# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('data_jobs.csv')
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
job_postings_jan = pd.DataFrame({
    'job_id': [101, 102, 103, 104],
    'job_title': ['Data Analyst', 'Machine Learning Engineer', 'Business Analyst', 'AI Engineer'],
    'company': ['DataCorp', 'AI Labs', 'BizTech', 'NeuroSoft'],
    'job_posted_date': ['2025-01-05', '2025-01-12', '2025-01-20', '2025-01-28']
})

# DataFrame 2: Job Postings in February
job_postings_feb = pd.DataFrame({
    'job_id': [201, 202, 203, 204],
    'job_title': ['Data Scientist', 'Product Analyst', 'Deep Learning Engineer', 'Data Engineer'],
    'company': ['InsightAI', 'MarketGenie', 'VisionTech', 'CloudWare'],
    'job_posted_date': ['2025-02-03', '2025-02-10', '2025-02-18', '2025-02-25']
})

# %%
job_postings_jan
# Out:
#    job_id                  job_title    company job_posted_date
# 0     101               Data Analyst   DataCorp      2025-01-05
# 1     102  Machine Learning Engineer    AI Labs      2025-01-12
# 2     103           Business Analyst    BizTech      2025-01-20
# 3     104                AI Engineer  NeuroSoft      2025-01-28

# %%
job_postings_feb
# Out:
#    job_id               job_title      company job_posted_date
# 0     201          Data Scientist    InsightAI      2025-02-03
# 1     202         Product Analyst  MarketGenie      2025-02-10
# 2     203  Deep Learning Engineer   VisionTech      2025-02-18
# 3     204           Data Engineer    CloudWare      2025-02-25

# %%
pd.concat([job_postings_jan,job_postings_feb]).reset_index()
# Out:
#    index  job_id                  job_title      company job_posted_date
# 0      0     101               Data Analyst     DataCorp      2025-01-05
# 1      1     102  Machine Learning Engineer      AI Labs      2025-01-12
# 2      2     103           Business Analyst      BizTech      2025-01-20
# 3      3     104                AI Engineer    NeuroSoft      2025-01-28
# 4      0     201             Data Scientist    InsightAI      2025-02-03
# 5      1     202            Product Analyst  MarketGenie      2025-02-10
# 6      2     203     Deep Learning Engineer   VisionTech      2025-02-18
# 7      3     204              Data Engineer    CloudWare      2025-02-25

# %%
df['job_posted_month'] = df['job_posted_date'].dt.strftime('%b')
df
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %%
months = df['job_posted_month'].unique()
months
# Out:
# array(['Jun', 'Jan', 'Oct', 'Jul', 'Aug', 'Nov', 'Mar', 'Dec', 'Apr',
#        'Feb', 'Sep', 'May'], dtype=object)

# %%
dict_month = {month: df[df['job_posted_month'] == month] for month in months}
dict_month['Jan']
# Out:
#           job_title_short                                  job_title  \
# 1            Data Analyst                               Data Analyst
# 20         Data Scientist                             Data Scientist
# 39          Data Engineer                              Data Engineer
# 53          Data Engineer                              Data Engineer
# 55         Data Scientist                             Data Scientist
# ...                   ...                                        ...
# 785699  Software Engineer                        Simulation Engineer
# 785700      Data Engineer                       Data Engineer Ssr/Sr
# 785703       Data Analyst    Data Analyst - CRYPTOGRAPHY - Full-time
# 785704   Business Analyst                           Business Analyst
# 785705       Data Analyst  Expert Business Data Analyst - Now Hiring
#
#                                  job_location             job_via  \
# 1                Guadalajara, Jalisco, Mexico    via BeBee México
# ...

# %%
df_q1=pd.concat([dict_month['Jan'],dict_month['Feb'],dict_month['Mar']],ignore_index=True)

# %%
df_q1['job_posted_month'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='job_posted_month'>

# %%
df_endq = pd.concat([dict_month['Oct'],dict_month['Nov'],dict_month['Dec']],ignore_index=True)

# %%
df_endq['job_posted_month'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='job_posted_month'>
