# %%
import pandas as pd
import matplotlib.pyplot as plt
import ast

df = pd.read_csv('data_jobs.csv')
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
df['job_skills'] = df['job_skills'].apply(lambda skill_list: ast.literal_eval(skill_list) if pd.notna(skill_list) else skill_list)

# %%
df['job_work_from_home'].value_counts().plot(kind='pie')
plt.title('Work from Home Status')
plt.ylabel('')
plt.show()

# %%
df['job_title_short'].value_counts().plot(kind='pie',autopct = '%.1f%%')
plt.ylabel('')
plt.title('Job Titles in The Dataset')
# Out:
# Text(0.5, 1.0, 'Job Titles in The Dataset')

# %%
df['job_work_from_home'].value_counts().plot(kind='pie', startangle = 90,autopct = '%.1f%%')
plt.title('Work from Home Status')
plt.ylabel('')
plt.show()

# %%
df_bool = df[['job_work_from_home','job_no_degree_mention','job_health_insurance']]

# %%
fig, ax = plt.subplots(1,3)

for i,column in enumerate(df_bool): 
    ax[i].pie(df[column].value_counts(),autopct  = '%.1f%%',startangle = 90,labels = ['False','True'])
    ax[i].set_title(column)

fig.tight_layout()
plt.show()
