# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('data_jobs.csv')
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df.sample(10)
# Out:
#                   job_title_short  \
# 22400               Data Engineer
# 118676             Data Scientist
# 426597               Data Analyst
# 598742               Data Analyst
# 309392             Data Scientist
# 197959               Data Analyst
# 659932               Data Analyst
# 123555  Machine Learning Engineer
# 557304           Business Analyst
# 265267               Data Analyst
#
#                                                 job_title  \
# 22400                             Data Warehouse Engineer
# 118676                                         Líder Data
# 426597  Apprenti.e Ingénieur.e Data Analyst (H/F) : Du...
# 598742       Lead Research & Data Analyst (Milwaukee, WI)
# 309392                                     Data Scientist
# 197959                             Reporting Data Analyst
# 659932                      Data Analyst Business Analyst
# 123555                   Junior Machine Learning Engineer
# 557304                          Cientista de Dados Sênior
# 265267                             Team Lead Data Quality
#
#                                        job_location                job_via  \
# 22400                                Beijing, China                 via 领英
# 118676                 Guadalajara, Jalisco, Mexico              via BeBee
# 426597                                Paris, France           via Jobijoba
# 598742                                Milwaukee, WI           via Built In
# 309392                    Ahmedabad, Gujarat, India             via Indeed
# 197959                                    Tampa, FL              via BeBee
# 659932                                        India        via BeBee India
# 123555                              Sofia, Bulgaria  via LinkedIn Bulgaria
# 557304  Natal, State of Rio Grande do Norte, Brazil              via BeBee
# 265267                               Moscow, Russia              via hh.ru
#
#        job_schedule_type  job_work_from_home          search_location  \
# 22400          Full-time               False                    China
# 118676         Full-time               False                   Mexico
# 426597               NaN               False                   France
# 598742         Full-time               False  Illinois, United States
# 309392         Full-time               False                    India
# 197959         Full-time               False   Florida, United States
# 659932         Full-time               False                    India
# 123555         Full-time               False                 Bulgaria
# 557304         Full-time               False                   Brazil
# 265267         Full-time               False                   Russia
#
#            job_posted_date  job_no_degree_mention  job_health_insurance  \
# 22400  2023-01-13 14:18:27                  False                 False
# 118676 2023-07-29 08:18:39                  False                 False
# 426597 2023-03-04 16:33:10                  False                 False
# 598742 2023-08-19 09:01:58                  False                  True
# 309392 2023-06-27 17:34:13                  False                 False
# 197959 2023-03-24 15:04:46                   True                 False
# 659932 2023-12-02 10:23:33                   True                 False
# 123555 2023-01-17 08:17:53                  False                 False
# 557304 2023-10-02 04:19:51                  False                 False
# 265267 2023-03-13 07:47:26                  False                 False
#
#           job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 22400           China         NaN              NaN              NaN
# 118676         Mexico         NaN              NaN              NaN
# 426597         France         NaN              NaN              NaN
# 598742  United States        year         139900.0              NaN
# 309392          India         NaN              NaN              NaN
# 197959  United States         NaN              NaN              NaN
# 659932          India         NaN              NaN              NaN
# 123555       Bulgaria         NaN              NaN              NaN
# 557304         Brazil         NaN              NaN              NaN
# 265267         Russia         NaN              NaN              NaN
#
#                               company_name  \
# 22400                               法国兴业银行
# 118676  GRIVER- Grupo Inversor Veracruzano
# 426597                          Technipfmc
# 598742                 Northwestern Mutual
# 309392          Sai Management Consultancy
# 197959   Alvarez & Marsal Deutschland GmbH
# 659932                Prometrics Solutions
# 123555               The Coca-Cola Company
# 557304                           BairesDev
# 265267                      Группа Самолет
#
#                                                job_skills  \
# 22400                ['sql', 'java', 'postgresql', 'git']
# 118676  ['python', 'r', 'java', 'sql', 'mongodb', 'mon...
# 426597                    ['python', 'sql', 'r', 'mysql']
# 598742                              ['sql', 'powerpoint']
# 309392                              ['python', 'seaborn']
# 197959                                          ['excel']
# 659932                                ['excel', 'sheets']
# 123555  ['scala', 'sql', 'azure', 'databricks', 'spark...
# 557304                             ['sql', 'python', 'r']
# 265267   ['sql', 'python', 'excel', 'jira', 'confluence']
#
#                                           job_type_skills
# 22400   {'databases': ['postgresql'], 'other': ['git']...
# 118676  {'analyst_tools': ['power bi'], 'cloud': ['azu...
# 426597  {'databases': ['mysql'], 'programming': ['pyth...
# 598742  {'analyst_tools': ['powerpoint'], 'programming...
# 309392  {'libraries': ['seaborn'], 'programming': ['py...
# 197959                       {'analyst_tools': ['excel']}
# 659932             {'analyst_tools': ['excel', 'sheets']}
# 123555  {'cloud': ['azure', 'databricks'], 'libraries'...
# 557304            {'programming': ['sql', 'python', 'r']}
# 265267  {'analyst_tools': ['excel'], 'async': ['jira',...

# %%
df_altered = df.copy()

df_altered
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# 785739  Principal Associate, Data Engineer (Remote-Eli...
# 785740                                 AWS System Analyst
#
#                                job_location                    job_via  \
# 0                             Watertown, CT            via Work Nearby
# 1              Guadalajara, Jalisco, Mexico           via BeBee México
# 2                           Berlin, Germany               via LinkedIn
# 3                           San Antonio, TX          via Diversity.com
# 4                            Washington, DC         via Clearance Jobs
# ...                                     ...                        ...
# 785736                            Singapura        melalui Trabajo.org
# 785737                   Bad Rodach, Jerman  melalui BeBee Deutschland
# 785738                             Malaysia           melalui Ricebowl
# 785739  Newark, New Jersey, Amerika Serikat        melalui Recruit.net
# 785740                                India             melalui Trigyn
#
#        job_schedule_type  job_work_from_home       search_location  \
# 0              Full-time               False  Texas, United States
# 1              Full-time               False                Mexico
# 2              Full-time               False               Germany
# 3              Full-time               False  Texas, United States
# 4              Full-time               False                 Sudan
# ...                  ...                 ...                   ...
# 785736   Pekerjaan tetap               False             Singapore
# 785737   Pekerjaan tetap               False               Germany
# 785738   Pekerjaan tetap               False              Malaysia
# 785739   Pekerjaan tetap               False                 Sudan
# 785740   Pekerjaan tetap               False                 India
#
#            job_posted_date  job_no_degree_mention  job_health_insurance  \
# 0      2023-06-16 13:44:15                  False                 False
# 1      2023-01-14 13:18:07                  False                 False
# 2      2023-10-10 13:14:55                  False                 False
# 3      2023-07-04 13:01:41                   True                 False
# 4      2023-08-07 14:29:36                  False                 False
# ...                    ...                    ...                   ...
# 785736 2023-03-13 06:16:16                  False                 False
# 785737 2023-03-12 06:18:18                  False                 False
# 785738 2023-03-12 06:32:36                  False                 False
# 785739 2023-03-12 06:32:15                  False                 False
# 785740 2023-03-13 06:16:31                  False                 False
#
#           job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 0       United States         NaN         115000.0              NaN
# 1              Mexico         NaN         115000.0              NaN
# 2             Germany         NaN         115000.0              NaN
# 3       United States         NaN         115000.0              NaN
# 4               Sudan         NaN         115000.0              NaN
# ...               ...         ...              ...              ...
# 785736      Singapore         NaN         115000.0              NaN
# 785737        Germany         NaN         115000.0              NaN
# 785738       Malaysia         NaN         115000.0              NaN
# 785739          Sudan         NaN         115000.0              NaN
# 785740          India         NaN         115000.0              NaN
#
#                               company_name  \
# 0                     Boehringer Ingelheim
# 1               Hewlett Packard Enterprise
# 2                 ALPHA Augmented Services
# 3             Southwest Research Institute
# 4                          Kristina Daniel
# ...                                    ...
# 785736  CAREERSTAR INTERNATIONAL PTE. LTD.
# 785737                    HABA FAMILYGROUP
# 785738               Lendlease Corporation
# 785739                         Capital One
# 785740                              Trigyn
#
#                                                job_skills  \
# 0                                                     NaN
# 1       ['r', 'python', 'sql', 'nosql', 'power bi', 't...
# 2       ['python', 'sql', 'c#', 'azure', 'airflow', 'd...
# 3       ['python', 'c++', 'java', 'matlab', 'aws', 'te...
# 4       ['bash', 'python', 'oracle', 'aws', 'ansible',...
# ...                                                   ...
# 785736  ['bash', 'python', 'perl', 'linux', 'unix', 'k...
# 785737                     ['sas', 'sas', 'sql', 'excel']
# 785738                            ['powerpoint', 'excel']
# 785739  ['python', 'go', 'nosql', 'sql', 'mongo', 'she...
# 785740                                    ['aws', 'flow']
#
#                                           job_type_skills
# 0                                                     NaN
# 1       {'analyst_tools': ['power bi', 'tableau'], 'pr...
# 2       {'analyst_tools': ['dax'], 'cloud': ['azure'],...
# 3       {'cloud': ['aws'], 'libraries': ['tensorflow',...
# 4       {'cloud': ['oracle', 'aws'], 'other': ['ansibl...
# ...                                                   ...
# 785736  {'os': ['linux', 'unix'], 'other': ['kubernete...
# 785737  {'analyst_tools': ['sas', 'excel'], 'programmi...
# 785738         {'analyst_tools': ['powerpoint', 'excel']}
# 785739  {'cloud': ['aws', 'snowflake', 'azure', 'redsh...
# 785740              {'cloud': ['aws'], 'other': ['flow']}
#
# [785741 rows x 17 columns]

# %%
median_salary = df_altered['salary_year_avg'].median()
median_salary
# Out:
# 115000.0

# %%
df_altered['salary_year_avg'] = df_altered['salary_year_avg'].fillna(median_salary)
df_altered.loc[:5,'salary_year_avg']
# Out:
# 0    115000.0
# 1    115000.0
# 2    115000.0
# 3    115000.0
# 4    115000.0
# 5    115000.0
# Name: salary_year_avg, dtype: float64

# %%
id(df)
# Out:
# 2070852085392

# %%
df
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# 785739  Principal Associate, Data Engineer (Remote-Eli...
# 785740                                 AWS System Analyst
#
#                                job_location                    job_via  \
# 0                             Watertown, CT            via Work Nearby
# 1              Guadalajara, Jalisco, Mexico           via BeBee México
# 2                           Berlin, Germany               via LinkedIn
# 3                           San Antonio, TX          via Diversity.com
# 4                            Washington, DC         via Clearance Jobs
# ...                                     ...                        ...
# 785736                            Singapura        melalui Trabajo.org
# 785737                   Bad Rodach, Jerman  melalui BeBee Deutschland
# 785738                             Malaysia           melalui Ricebowl
# 785739  Newark, New Jersey, Amerika Serikat        melalui Recruit.net
# 785740                                India             melalui Trigyn
#
#        job_schedule_type  job_work_from_home       search_location  \
# 0              Full-time               False  Texas, United States
# 1              Full-time               False                Mexico
# 2              Full-time               False               Germany
# 3              Full-time               False  Texas, United States
# 4              Full-time               False                 Sudan
# ...                  ...                 ...                   ...
# 785736   Pekerjaan tetap               False             Singapore
# 785737   Pekerjaan tetap               False               Germany
# 785738   Pekerjaan tetap               False              Malaysia
# 785739   Pekerjaan tetap               False                 Sudan
# 785740   Pekerjaan tetap               False                 India
#
#            job_posted_date  job_no_degree_mention  job_health_insurance  \
# 0      2023-06-16 13:44:15                  False                 False
# 1      2023-01-14 13:18:07                  False                 False
# 2      2023-10-10 13:14:55                  False                 False
# 3      2023-07-04 13:01:41                   True                 False
# 4      2023-08-07 14:29:36                  False                 False
# ...                    ...                    ...                   ...
# 785736 2023-03-13 06:16:16                  False                 False
# 785737 2023-03-12 06:18:18                  False                 False
# 785738 2023-03-12 06:32:36                  False                 False
# 785739 2023-03-12 06:32:15                  False                 False
# 785740 2023-03-13 06:16:31                  False                 False
#
#           job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 0       United States         NaN         115000.0              NaN
# 1              Mexico         NaN         115000.0              NaN
# 2             Germany         NaN         115000.0              NaN
# 3       United States         NaN         115000.0              NaN
# 4               Sudan         NaN         115000.0              NaN
# ...               ...         ...              ...              ...
# 785736      Singapore         NaN         115000.0              NaN
# 785737        Germany         NaN         115000.0              NaN
# 785738       Malaysia         NaN         115000.0              NaN
# 785739          Sudan         NaN         115000.0              NaN
# 785740          India         NaN         115000.0              NaN
#
#                               company_name  \
# 0                     Boehringer Ingelheim
# 1               Hewlett Packard Enterprise
# 2                 ALPHA Augmented Services
# 3             Southwest Research Institute
# 4                          Kristina Daniel
# ...                                    ...
# 785736  CAREERSTAR INTERNATIONAL PTE. LTD.
# 785737                    HABA FAMILYGROUP
# 785738               Lendlease Corporation
# 785739                         Capital One
# 785740                              Trigyn
#
#                                                job_skills  \
# 0                                                     NaN
# 1       ['r', 'python', 'sql', 'nosql', 'power bi', 't...
# 2       ['python', 'sql', 'c#', 'azure', 'airflow', 'd...
# 3       ['python', 'c++', 'java', 'matlab', 'aws', 'te...
# 4       ['bash', 'python', 'oracle', 'aws', 'ansible',...
# ...                                                   ...
# 785736  ['bash', 'python', 'perl', 'linux', 'unix', 'k...
# 785737                     ['sas', 'sas', 'sql', 'excel']
# 785738                            ['powerpoint', 'excel']
# 785739  ['python', 'go', 'nosql', 'sql', 'mongo', 'she...
# 785740                                    ['aws', 'flow']
#
#                                           job_type_skills
# 0                                                     NaN
# 1       {'analyst_tools': ['power bi', 'tableau'], 'pr...
# 2       {'analyst_tools': ['dax'], 'cloud': ['azure'],...
# 3       {'cloud': ['aws'], 'libraries': ['tensorflow',...
# 4       {'cloud': ['oracle', 'aws'], 'other': ['ansibl...
# ...                                                   ...
# 785736  {'os': ['linux', 'unix'], 'other': ['kubernete...
# 785737  {'analyst_tools': ['sas', 'excel'], 'programmi...
# 785738         {'analyst_tools': ['powerpoint', 'excel']}
# 785739  {'cloud': ['aws', 'snowflake', 'azure', 'redsh...
# 785740              {'cloud': ['aws'], 'other': ['flow']}
#
# [785741 rows x 17 columns]

# %%
id(df_altered)
# Out:
# 2071073807696
