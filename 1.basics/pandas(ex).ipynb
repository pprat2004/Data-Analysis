# %%
import pandas as pd

# %%
df = pd.read_csv('data_jobs.csv')

# %%
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
df['job_country'].value_counts().head(20)
# Out:
# job_country
# United States     206292
# India              51088
# United Kingdom     40375
# France             39922
# Germany            27694
# Spain              25100
# Singapore          23696
# Sudan              21781
# Netherlands        20631
# Italy              17013
# Canada             16029
# Mexico             15139
# Poland             14793
# Portugal           14508
# Australia          12955
# South Africa       12414
# Belgium            12078
# Philippines        11786
# Ireland            11162
# Switzerland         9924
# Name: count, dtype: int64

# %%
india_jobs = df[df['job_country'] == 'India']

# %%
india_jobs
# Out:
#              job_title_short  \
# 16             Data Engineer
# 19            Data Scientist
# 29            Data Scientist
# 38              Data Analyst
# 42      Senior Data Engineer
# ...                      ...
# 785712         Data Engineer
# 785715          Data Analyst
# 785716     Software Engineer
# 785718      Business Analyst
# 785740     Software Engineer
#
#                                                 job_title  \
# 16                                      Big Data Engineer
# 19                                         Data Scientist
# 29                                         Data Scientist
# 38                  Data Quality and Governance Analyst 1
# 42            Senior Data Engineer(Python)-1563,1637&1633
# ...                                                   ...
# 785712                     India - Collections Analyst II
# 785715  Amul Careers 2023 - Apply Online - Data Analys...
# 785716                        Application Support Analyst
# ...

# %%
india_jobs = india_jobs.dropna(subset = ['salary_year_avg'])

# %%
india_jobs
# Out:
#                   job_title_short  \
# 1209    Machine Learning Engineer
# 2022                Data Engineer
# 2785                Data Engineer
# 3190         Senior Data Engineer
# 3930               Data Scientist
# ...                           ...
# 783733      Senior Data Scientist
# 784033               Data Analyst
# 784768             Data Scientist
# 785395              Data Engineer
# 785515               Data Analyst
#
#                                                 job_title  \
# 1209                      Computer Vision Developer (R&D)
# 2022                       Data Engineer - SQL (Power BI)
# 2785    Staff Software Engineer - Data Engineering (Ja...
# 3190         Senior Big Data DevOps & Deployment Engineer
# 3930                                  Lead Data Scientist
# ...                                                   ...
# 783733                              Senior Data Scientist
# 784033                           Recruitment Data Analyst
# ...

# %%
india_jobs = india_jobs.drop('salary_hour_avg',axis = 1)

# %%
india_jobs
# Out:
#                   job_title_short  \
# 1209    Machine Learning Engineer
# 2022                Data Engineer
# 2785                Data Engineer
# 3190         Senior Data Engineer
# 3930               Data Scientist
# ...                           ...
# 783733      Senior Data Scientist
# 784033               Data Analyst
# 784768             Data Scientist
# 785395              Data Engineer
# 785515               Data Analyst
#
#                                                 job_title  \
# 1209                      Computer Vision Developer (R&D)
# 2022                       Data Engineer - SQL (Power BI)
# 2785    Staff Software Engineer - Data Engineering (Ja...
# 3190         Senior Big Data DevOps & Deployment Engineer
# 3930                                  Lead Data Scientist
# ...                                                   ...
# 783733                              Senior Data Scientist
# 784033                           Recruitment Data Analyst
# ...

# %%
india_jobs.groupby('job_title_short')['salary_year_avg'].agg(['min','max','median','count']).sort_values('median',ascending = False)
# Out:
#                                min       max    median  count
# job_title_short
# Senior Data Scientist      64800.0  170575.0  149653.0     33
# Data Engineer              43200.0  249000.0  147500.0    169
# Senior Data Engineer       35000.0  181765.0  147500.0     57
# Data Scientist             43200.0  204381.0  114008.0     92
# Senior Data Analyst        64800.0  177283.0  111175.0     27
# Data Analyst               32400.0  650000.0  100500.0     94
# Machine Learning Engineer  32500.0  267000.0   79200.0     57
# Software Engineer          44418.5  200000.0   79200.0     45
# Business Analyst           43200.0  142025.0   64800.0      8
